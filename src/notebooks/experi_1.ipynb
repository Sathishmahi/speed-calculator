# %%
from IPython.display import Video

# %%
Video("/config/workspace/artifact/speed_calculator/output.mp4")
# Out:
# <video src="/config/workspace/artifact/speed_calculator/output.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
import cv2
imarr = cv2.VideoCapture("/config/workspace/artifact/speed_calculator/input.mp4").read()[-1]

# %%
imarr.shape
# Out:
# (720, 1280, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(cv2.circle(imarr,(50,1250),10,(255,0,0),cv2.FILLED))
